# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

tList = []
# to run this code effectively, my_path must be changed to wherever the data is on your computer
df = pd.read_csv("/Users/rohitvalmeekam/Desktop/cs124h/GOOG_DS2.csv")
# r-value
df["Average_Price"] = (df.High + df.Low) / 2
#r = np.corrcoef(df.Date,(df.Average_Price))
#print(r[0,1])

# Plot
plt.plot(df.Date, df.Average_Price)
plt.title("Average Google Stock Price Over Time")
plt.xlabel('Date')
plt.ylabel('Average_Price')
#plt.plot(df.Date,df.Average_Price/np.max(df.Average_Price))
#plt.scatter(df["observation_date"], roll2)
plt.show()
